# %% [markdown]
# Abdulaziz Almousa

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
chipo.head(30)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$', '', regex=False).astype(float)
chipo['unit_price'] = chipo['item_price'] / chipo['quantity']

(chipo[chipo['unit_price'] > 10][['item_name', 'choice_description']]
 .drop_duplicates()
 .shape[0])
# Out:
# 707

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
prices = chipo[['item_name', 'choice_description', 'item_price']].drop_duplicates()
prices
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4602                       Barbacoa Burrito
# 4607                          Steak Burrito
# 4610                          Steak Burrito
# 4611                         Veggie Burrito
# 4612                          Carnitas Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
prices.sort_values('item_name').reset_index(drop=True)
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                         [Lemonade]
# 1     6 Pack Soft Drink                                        [Diet Coke]
# 2     6 Pack Soft Drink                                             [Coke]
# 3     6 Pack Soft Drink                                           [Sprite]
# 4     6 Pack Soft Drink                                        [Diet Coke]
# ...                 ...                                                ...
# 1955  Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 1956  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 1957  Veggie Soft Tacos  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# 1958  Veggie Soft Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 1959  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
#
#       item_price
# 0           6.49
# 1           6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[chipo['item_price'] == chipo['item_price'].max()][['item_name', 'quantity', 'item_price']]
# Out:
#                          item_name  quantity  item_price
# 3598  Chips and Fresh Tomato Salsa        15       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
len(chipo[chipo['item_name'] == 'Veggie Salad Bowl'])
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
len(chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)])
# Out:
# 20
