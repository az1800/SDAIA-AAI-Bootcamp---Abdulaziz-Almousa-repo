# %% [markdown]
# # M2.Ex3: Enrichment
#
# Docling allows to [enrich the conversion pipeline](https://docling-project.github.io/docling/usage/enrichments/) with additional steps which process specific document components, e.g. code blocks, pictures, etc. The extra steps usually require extra models executions which may increase the processing time consistently. For this reason most enrichment models are disabled by default.

# %%
# !pip install docling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 kB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 108.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 112.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 43.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Task 1: Picture Classification
#
# The picture classification step classifies the `PictureItem` elements in the document with the `DocumentFigureClassifier` model. This model is specialized to understand the classes of pictures found in documents, e.g. different chart types, flow diagrams, logos, signatures, etc.

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat

pipeline_options = PdfPipelineOptions()
pipeline_options.generate_picture_images = True
pipeline_options.images_scale = 2
pipeline_options.do_picture_classification = True

converter = DocumentConverter(format_options={
    InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
})

result = converter.convert("https://arxiv.org/pdf/2501.17887")
doc = result.document
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/360 [00:00<?, ?it/s]
# [INFO] 2026-05-04 08:42:03,070 [RapidOCR] base.py:22: Using engine_name: torch
# ...

# %% [markdown]
# Inspect the predicted classes on each `PictureItem`:

# %%
for picture in doc.pictures:
    print(f"Picture {picture.self_ref}")
    for annotation in picture.annotations:
        if annotation.kind == "classification":
            for cls in annotation.predicted_classes:
                print(f"  {cls.class_name}: {cls.confidence:.3f}")
# Out:
# Picture #/pictures/0
#   flow_chart: 0.751
#   bar_chart: 0.081
#   table: 0.077
#   calendar: 0.050
#   full_page_image: 0.013
#   engineering_drawing: 0.011
#   screenshot_from_computer: 0.003
#   line_chart: 0.003
#   screenshot_from_manual: 0.003
#   icon: 0.002
#   other: 0.002
#   page_thumbnail: 0.001
#   geographical_map: 0.001
#   pie_chart: 0.001
#   box_plot: 0.001
#   music: 0.001
#   crossword_puzzle: 0.000
#   logo: 0.000
#   chemistry_structure: 0.000
#   qr_code: 0.000
#   photograph: 0.000
#   scatter_plot: 0.000
#   stamp: 0.000
#   bar_code: 0.000
#   signature: 0.000
#   topographical_map: 0.000
# Picture #/pictures/1
#   pie_chart: 0.974
#   bar_chart: 0.019
#   table: 0.002
#   line_chart: 0.002
#   full_page_image: 0.001
#   other: 0.001
#   calendar: 0.000
#   engineering_drawing: 0.000
#   flow_chart: 0.000
#   screenshot_from_manual: 0.000
#   geographical_map: 0.000
#   scatter_plot: 0.000
#   page_thumbnail: 0.000
#   music: 0.000
# ...

# %% [markdown]
# ## Task 2: Picture Description
#
# The picture description step allows to annotate a picture with a vision model. This is also known as a "captioning" task.

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions, smolvlm_picture_description
from docling.datamodel.base_models import InputFormat

pipeline_options = PdfPipelineOptions()
pipeline_options.do_picture_description = True
pipeline_options.picture_description_options = smolvlm_picture_description

converter = DocumentConverter(format_options={
    InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
})

result = converter.convert("https://arxiv.org/pdf/2501.17887")
doc = result.document
# Out:
# Loading weights:   0%|          | 0/471 [00:00<?, ?it/s]
# [INFO] 2026-05-04 08:44:04,606 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-04 08:44:04,608 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-05-04 08:44:04,808 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-05-04 08:44:04,809 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-05-04 08:44:05,053 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-04 08:44:05,055 [RapidOCR] device_config.py:64: Using GPU device with ID: 0
# [INFO] 2026-05-04 08:44:05,073 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %% [markdown]
# Inspect the generated captions on each `PictureItem`:

# %%
for picture in doc.pictures:
    print(f"Picture {picture.self_ref}")
    for annotation in picture.annotations:
        if annotation.kind == "description":
            print(f"  {annotation.text}")
# Out:
# Picture #/pictures/0
#   In this image there is a table. In the table there are some images and some text.
# Picture #/pictures/1
#   The image is a pie chart titled "Documents per Category." The pie chart is divided into four sections, each representing a different category: "Science," "Patents," "Law and Regulations," and "CcPdf (misc)." The chart is color-coded to represent the number of pages per category.
#
# The pie chart is divided into four sections:
# 1. "Science"
# 2. "Patents"
# 3. "Law and Regulations"
# 4. "CcPdf (misc)"
#
# Each section is colored in a different color, with the largest section in the center being blue, the next largest in red, and the smallest in green.
#
# The chart is labeled with the following text:
# - "Documents per Category"
# - "Science"
# - "Patents"
# - "Law and Regulations"
# - "CcPdf (misc)"
#
# The pie chart is titled "Documents per Category" and is labeled
# Picture #/pictures/2
# ...
